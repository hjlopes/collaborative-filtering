# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse.linalg import svds

from sklearn.metrics.pairwise import pairwise_distances 
from sklearn.model_selection import train_test_split

data_path = '../data/21B_tag_views_dataset.csv'

# %% [markdown]
# # User-based Collaborative Filtering
#
# ## Data preparation
#
# Data loading and user/tag freq matrix

# %%
data = pd.read_csv(data_path)

# %%
data.head()
# Out:
#    id                                   user_id  \
# 0   1  00000055a78bf6735c4a89358fab1de34104c3cb
# 1   2  00000055a78bf6735c4a89358fab1de34104c3cb
# 2   3  00000055a78bf6735c4a89358fab1de34104c3cb
# 3   4  00000055a78bf6735c4a89358fab1de34104c3cb
# 4   5  00000055a78bf6735c4a89358fab1de34104c3cb
#
#                                      tag_id  \
# 0  e78de9dad70d230a096f0bbdc3e89b5cae04ba77
# 1  b9a521730141de9bc4fe8ebc9f33713411d0101a
# 2  8378136c6dd0e03be859a210a0cee03955951fb1
# 3  9cc68d8345f675892bcab0fad02f65b4ac7e71ea
# 4  a8272c62cd05d5b882e4f630fb55cfa0ba8491e6
#
#                                         product_name
# 0            La Gar̤onne In Oro Rosa A Maglie/bianco
# 1                                    Fishnet Eco Bag
# 2  Collarino Essentielle In Oro Interamente A Esa...
# 3    Asos - Vestito A Fascia Con Fondo A Fisarmonica
# 4                Peggy Off Shoulder Corset Top-white

# %%
tag_count_df = data.groupby(['user_id', 'tag_id']).agg({'tag_id': 'count'}).rename(columns={'tag_id':'tag_count'})
tag_count_df = tag_count_df.reset_index()

# %%
tag_count_df.head()
# Out:
#                                     user_id  \
# 0  00000055a78bf6735c4a89358fab1de34104c3cb
# 1  00000055a78bf6735c4a89358fab1de34104c3cb
# 2  00000055a78bf6735c4a89358fab1de34104c3cb
# 3  00000055a78bf6735c4a89358fab1de34104c3cb
# 4  00000055a78bf6735c4a89358fab1de34104c3cb
#
#                                      tag_id  tag_count
# 0  5c61cd1b82ec7a4d2918a6de99fcd1577b462f79          1
# 1  8378136c6dd0e03be859a210a0cee03955951fb1          1
# 2  9cc68d8345f675892bcab0fad02f65b4ac7e71ea          1
# 3  a1437d6393ee9535248b16f27a649bbd98c9e2f5          1
# 4  a8272c62cd05d5b882e4f630fb55cfa0ba8491e6          1

# %%
group_user_tag_count = tag_count_df.groupby('user_id').count()
print("number of users:", group_user_tag_count.shape[0])
# Out:
# number of users: 859

# %% [markdown]
# Remove users which have less than 3 tags

# %%
idx = group_user_tag_count[(group_user_tag_count['tag_count'] >= 3)].index
tag_count_df = tag_count_df[tag_count_df['user_id'].isin(idx)]

# %%
tag_count_df.groupby('user_id').count().shape
# Out:
# (555, 2)

# %% [markdown]
# ### Create an evaluation set

# %%
train_df, test_df = train_test_split(tag_count_df, test_size=0.33, stratify=tag_count_df['user_id'], 
                                     random_state=2019)

# %%
train_df.head()
# Out:
#                                        user_id  \
# 3451  001fcc3fbbb0018342194d97453fcac9431b8b8d
# 7677  0046db9c93d12e84b83fb852e48c6ea478d0cf9f
# 7691  0046eba9057fe724911c1dfb7e1d89efe4180912
# 7120  0040a6b97d2e61fef5eb404baf24867a4d3448a5
# 4756  0028c76d3882ac1de97c710a5c1ec65a54174de7
#
#                                         tag_id  tag_count
# 3451  911233d3bd7439f816b59c4d0358d5b3d1180db3          1
# 7677  849559737e3aa045f936886bd90aa43633e26172          1
# 7691  b576bce562c9ac7ae1a2b6d8d17b9875f9c1d476          1
# 7120  8be5f988077faab8b95e481a7a13f9d895db14f2          1
# 4756  4ae75b3f956a77966e595767e2a456f00bcd835b          1

# %%
train_user_tags_df = train_df.pivot(index='user_id', columns='tag_id', values='tag_count').fillna(0)

# %%
test_df = test_df.set_index('user_id')

# %%
test_df.head()
# Out:
#                                                                             tag_id  \
# user_id
# 002c887f87f2741e34bdabad89b622389dd6b6c8  d51cd4cbf68c39cc679c84fb93b7180757e895d6
# 0058eecfe79ec9c75f7085fd8d80ce796a4fdf6e  9dec895921afac3b79d79caed6528fa0cef16b85
# 00322da4f93da9932f49e5f346beae6e72475c88  9a326d8e613a25001392cc42903bcfe8cdc1e5ff
# 0044a0c70865331db0adf7f350dea93442b869fd  2b0545bd678d20da70950fd780cf371f64946ab7
# 003508ad2971d0413183983061bdb3c2a455d88a  3515d80ed2a0ce83f79afeb031349c261d95f707
#
#                                           tag_count
# user_id
# 002c887f87f2741e34bdabad89b622389dd6b6c8          1
# 0058eecfe79ec9c75f7085fd8d80ce796a4fdf6e          1
# 00322da4f93da9932f49e5f346beae6e72475c88          1
# 0044a0c70865331db0adf7f350dea93442b869fd          1
# 003508ad2971d0413183983061bdb3c2a455d88a          1

# %% [markdown]
# ## Collaborative model engine with matrix decomposition

# %%
def matrix_decomposition(n_factors):
    u, sigma, v = svds(train_user_tags_df.values, k=n_factors)
    sigma = np.diag(sigma)
    user_predictions = np.dot(np.dot(u, sigma), v)
    return pd.DataFrame(user_predictions, columns=train_user_tags_df.columns, index=train_user_tags_df.index)

# %%
predictions_df = matrix_decomposition(n_factors = 30)
predictions_df.head()
# Out:
# tag_id                                    00410345e6d60633a211ebd3755d5c89ea7b5297  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                             -2.766864e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              2.252433e-04
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                             -2.236487e-03
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              2.226605e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                             -1.544546e-18
#
# tag_id                                    005703ee98894846cde759fbe88f3d7fde830c85  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                              1.983152e-02
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              7.157366e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              9.305947e-04
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              3.202278e-03
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              4.728551e-20
#
# tag_id                                    0076e2a45d90991150032dbfaa574b4b7ab21177  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                              6.257567e-04
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              1.464573e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                             -1.032810e-03
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              6.859005e-03
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                             -1.344747e-18
#
# tag_id                                    0087f6286f5bd4f872620555b3e3b880e21de444  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                              4.511680e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              1.372593e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                             -3.682103e-03
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              2.563752e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                             -3.042988e-18
#
# tag_id                                    008a19c4e6b27ade78d422f9deaba16ef195772b  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                             -2.471830e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                             -2.531907e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              1.232474e-02
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                             -1.566725e-03
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                             -5.218651e-19
#
# tag_id                                    0108e35fbb3bb7e60c2045386294914255f137eb  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                             -3.873215e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              1.173938e-04
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                             -1.220585e-02
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                             -1.031952e-03
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              2.443752e-18
#
# tag_id                                    01c1f1173136b005f885c4691db374d4762f15e0  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                             -2.439340e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              7.325514e-04
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              1.645196e-03
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              2.435927e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              9.664560e-19
#
# tag_id                                    022f8f30c65aaeb13def1fb9d700c1937e30da06  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                              6.347881e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              3.867707e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              4.976940e-02
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              3.533251e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              3.658470e-19
#
# tag_id                                    0245aa04713eb538ebcb6d6c5667a55f5920d535  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                              7.761667e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              1.712029e-04
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                             -9.707537e-03
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                             -3.126543e-03
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                             -2.581234e-18
#
# tag_id                                    02a5da421359cb69816444a48f35c0cb01806ca6  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                              5.169462e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                             -2.338885e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              6.842038e-03
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              1.172076e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              2.437094e-18
#
# tag_id                                    ...  \
# user_id                                   ...
# 00000055a78bf6735c4a89358fab1de34104c3cb  ...
# 000014674d2afbd30b4a89e7f917b67ade3c31c4  ...
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9  ...
# 00009c599dca6873a47404fa9b7a9b0a1bd13049  ...
# 0000a8c248465bc8cd907e112b5c2f1e94424f28  ...
#
# tag_id                                    fd9b6d215102521471bdd20b88eef7e471a5f08c  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                             -2.215744e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                             -5.490988e-04
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              3.547152e-02
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                             -2.327890e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              6.805206e-18
#
# tag_id                                    fde652531ae50c7def995f5c5c2b067cd9bdc9de  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                             -5.257891e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              2.696509e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              9.021001e-04
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                             -1.872252e-03
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                             -2.590071e-19
#
# tag_id                                    fe0f9fd1fdfe652523ed4a3a9e57375301bf7144  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                             -5.692199e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                             -1.377479e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                             -2.038891e-03
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                             -4.260436e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                             -2.379637e-19
#
# tag_id                                    fe2297da6fbc7992a934f8ce4c848584d73bd1c3  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                             -1.005089e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                             -9.073557e-04
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                             -4.448768e-03
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              1.248163e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              7.630619e-19
#
# tag_id                                    fe5cd317975ca5dada3d9d047133f1925e460053  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                             -3.894122e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              6.164411e-04
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              4.484566e-03
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              3.923148e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              2.552223e-18
#
# tag_id                                    fe9cd8d22101c48eca5bc3eee51b9dc5e07fe683  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                              3.281620e-05
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              5.943258e-05
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                             -5.378293e-04
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                             -3.448356e-03
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              2.878806e-21
#
# tag_id                                    fe9e7151b6ae2070c053a80fa37862cfef449cae  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                              3.521641e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                             -1.013057e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              2.065431e-02
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              2.389488e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              4.423756e-18
#
# tag_id                                    fed8505b88adf6d879b4df147b29a068d98faa72  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                              8.114178e-04
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                             -3.521255e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              1.694823e-02
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              6.294212e-02
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                              3.778049e-18
#
# tag_id                                    ff0257af2bc7c28cd397a820aa33cde0d04b58b8  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                             -8.013274e-03
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              5.958806e-03
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              1.057100e-03
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                             -4.532238e-03
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                             -5.013698e-19
#
# tag_id                                    ff0d3fb21c00bc33f71187a2beec389e9eff5332
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                              1.922221e-02
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                              8.790847e-04
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                              1.005686e-02
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                              1.193290e-03
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                             -6.446025e-19
#
# [5 rows x 989 columns]

# %%
def get_user_predictions(user, predictions, n_preds, not_seen=True):
    """
    user: str user id
    predictions: pd.DataFrame of user_id/tag_id with predictions 'score'
    n_preds: int number of predictions to return
    not_seen: bool flag to return user seen predictions or not
    """
    user_predictions = predictions.loc[user].sort_values(ascending=False).reset_index()
    user_products = data[data['user_id']==user]['tag_id']
    if not_seen:
        user_predictions = user_predictions[~user_predictions['tag_id'].isin(user_products)]
    return user_predictions[:n_preds]

# %% [markdown]
# **Note**: The precision metric here is a bit useless, si nce it will highly depend on how many tags we want to show, and how many tags the user has seen which could be less than those we want to show, and therefore lowering the metric.

# %%
def eval_model(predictions, test):
    recall_list = []
    precision_list = []
    for i, user_id in enumerate(predictions.index.unique().values):
        test_user_tags = test.loc[user_id]['tag_id']
        user_preds = get_user_predictions(user_id, predictions, 10, False)
        # Match tags in test with those in the predictions
        matched_tags_bool = user_preds['tag_id'].isin(pd.Series(test_user_tags))
        
        true_positives = matched_tags_bool.sum()
        if type(test_user_tags) == str:
            user_recall = true_positives / (true_positives + 1 - true_positives) # sometimes it will get only 1 element which is a string
            user_precision = true_positives / (1 + len(user_preds) - true_positives)
        else:
            user_recall = true_positives / (true_positives + len(test_user_tags) - true_positives)
            user_precision = true_positives / (len(test_user_tags) + len(user_preds) - true_positives)
        recall_list.append(user_recall)
        precision_list.append(user_precision)
        
    recall = sum(recall_list)/test.shape[0]
    precision = sum(precision_list)/test.shape[0]
    print("Recall:", recall*100)
    print("Precision:", precision*100)

        
eval_model(predictions_df, test_df)
# Out:
# Recall: 2.131267282196077
# Precision: 0.5635654652483083

# %%
preds_15_df = matrix_decomposition(n_factors = 15)
eval_model(preds_15_df, test_df)
# Out:
# Recall: 1.6832546230632066
# Precision: 0.5132753391297613

# %%
preds_50_df = matrix_decomposition(n_factors = 50)
eval_model(preds_50_df, test_df)
# Out:
# Recall: 2.5653930499902065
# Precision: 0.6030131716814621

# %%
preds_50_df = matrix_decomposition(n_factors = 60)
eval_model(preds_50_df, test_df)
# Out:
# Recall: 2.599453118410464
# Precision: 0.5956516307638045

# %% [markdown]
# ## Collaborative model engine with cosine distance

# %%
def cosine_distance_model():
    item_similarity = pairwise_distances(train_user_tags_df.values.T, metric='cosine')
    user_predictions = train_user_tags_df.values.dot(item_similarity)/np.abs(item_similarity.sum(axis=1))
    # Here we are dealing with distances, so the lower the distance the best, which is the inverse of the SDV 
    user_predictions = 1 / (1 + user_predictions)
    return pd.DataFrame(user_predictions, columns=train_user_tags_df.columns, index=train_user_tags_df.index)

# %%
cosine_predictions_df = cosine_distance_model()
cosine_predictions_df.head()
# Out:
# tag_id                                    00410345e6d60633a211ebd3755d5c89ea7b5297  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994815
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993785
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997920
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979654
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997920
#
# tag_id                                    005703ee98894846cde759fbe88f3d7fde830c85  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.995689
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994361
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997961
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979187
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997961
#
# tag_id                                    0076e2a45d90991150032dbfaa574b4b7ab21177  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994745
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993701
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998100
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979387
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997891
#
# tag_id                                    0087f6286f5bd4f872620555b3e3b880e21de444  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994867
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993846
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997940
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979635
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997940
#
# tag_id                                    008a19c4e6b27ade78d422f9deaba16ef195772b  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994706
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993653
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998154
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979166
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997875
#
# tag_id                                    0108e35fbb3bb7e60c2045386294914255f137eb  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994721
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993672
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998039
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978754
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997882
#
# tag_id                                    01c1f1173136b005f885c4691db374d4762f15e0  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994748
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993704
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998055
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979388
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997893
#
# tag_id                                    022f8f30c65aaeb13def1fb9d700c1937e30da06  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994716
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993801
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998373
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979343
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997880
#
# tag_id                                    0245aa04713eb538ebcb6d6c5667a55f5920d535  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994974
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993766
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997913
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978883
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997913
#
# tag_id                                    02a5da421359cb69816444a48f35c0cb01806ca6  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994776
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993738
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998065
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979796
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997904
#
# tag_id                                    ...  \
# user_id                                   ...
# 00000055a78bf6735c4a89358fab1de34104c3cb  ...
# 000014674d2afbd30b4a89e7f917b67ade3c31c4  ...
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9  ...
# 00009c599dca6873a47404fa9b7a9b0a1bd13049  ...
# 0000a8c248465bc8cd907e112b5c2f1e94424f28  ...
#
# tag_id                                    fd9b6d215102521471bdd20b88eef7e471a5f08c  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994722
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993673
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998347
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979164
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997882
#
# tag_id                                    fde652531ae50c7def995f5c5c2b067cd9bdc9de  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994913
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994354
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997959
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978976
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997959
#
# tag_id                                    fe0f9fd1fdfe652523ed4a3a9e57375301bf7144  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994751
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993708
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997988
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978511
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997894
#
# tag_id                                    fe2297da6fbc7992a934f8ce4c848584d73bd1c3  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994762
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993720
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998054
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979543
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997898
#
# tag_id                                    fe5cd317975ca5dada3d9d047133f1925e460053  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994871
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993852
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998054
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979694
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997942
#
# tag_id                                    fe9cd8d22101c48eca5bc3eee51b9dc5e07fe683  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994960
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993958
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997978
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979169
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997978
#
# tag_id                                    fe9e7151b6ae2070c053a80fa37862cfef449cae  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994730
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993683
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998255
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979751
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997885
#
# tag_id                                    fed8505b88adf6d879b4df147b29a068d98faa72  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994782
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993925
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998072
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979471
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997906
#
# tag_id                                    ff0257af2bc7c28cd397a820aa33cde0d04b58b8  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994918
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994110
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997961
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978997
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997961
#
# tag_id                                    ff0d3fb21c00bc33f71187a2beec389e9eff5332
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.995171
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.993833
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.998048
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.979219
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.997936
#
# [5 rows x 989 columns]

# %%
get_user_predictions(cosine_predictions_df.index[0], cosine_predictions_df, 10)
# Out:
#                                       tag_id  \
# 5   7920408a188a51d437a48a707f9e71277c9d8335
# 6   e531c1dad33434c9d7a323f7928cae9cf04f9f7a
# 7   a75c8e7b72c5e7d363911e1b02932b0563fa5a6a
# 8   3f736ea31dc289439c2868ef54b0fcb8ea3be3b9
# 9   6979b2dff5cd1530f7fe498d96efb1bff3b549cf
# 10  9f5cd26abfc96a97f8ee874d132c526a0fccb382
# 11  a4f57d548918c1aabeec80a99078853e849bd65c
# 12  ceb10adfb4b5b50f5bd2e01d1cc797c71e01a77c
# 13  3e4d8d24daf15692515999d4c8809eac1a3ee55c
# 14  29d400c6bada3de9543bcd931729848b5a95cdd6
#
#     00000055a78bf6735c4a89358fab1de34104c3cb
# 5                                   0.996253
# 6                                   0.996221
# 7                                   0.996176
# 8                                   0.996087
# 9                                   0.996036
# 10                                  0.995998
# 11                                  0.995918
# 12                                  0.995893
# 13                                  0.995891
# 14                                  0.995847

# %%
eval_model(cosine_predictions_df, test_df)
# Out:
# Recall: 2.9036334913112163
# Precision: 0.4884231092761901

# %% [markdown]
# ## Collaborative model engine with euclidean distance

# %%
def euclidean_distance_model():
    item_similarity = pairwise_distances(train_user_tags_df.values.T, metric='euclidean')
    user_predictions = train_user_tags_df.values.dot(item_similarity)/np.abs(item_similarity.sum(axis=1))
    user_predictions = 1 / (1 + user_predictions)
    return pd.DataFrame(user_predictions, columns=train_user_tags_df.columns, index=train_user_tags_df.index)

# %%
euclidean_predictions_df = euclidean_distance_model()
euclidean_predictions_df.head()
# Out:
# tag_id                                    00410345e6d60633a211ebd3755d5c89ea7b5297  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994949
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994602
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997159
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977724
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998639
#
# tag_id                                    005703ee98894846cde759fbe88f3d7fde830c85  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.995410
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994809
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997260
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977650
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998574
#
# tag_id                                    0076e2a45d90991150032dbfaa574b4b7ab21177  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994907
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994339
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997491
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978102
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998391
#
# tag_id                                    0087f6286f5bd4f872620555b3e3b880e21de444  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994975
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994629
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997173
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977687
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998646
#
# tag_id                                    008a19c4e6b27ade78d422f9deaba16ef195772b  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994893
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994469
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997356
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977648
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998543
#
# tag_id                                    0108e35fbb3bb7e60c2045386294914255f137eb  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994884
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994185
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997603
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978058
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998252
#
# tag_id                                    01c1f1173136b005f885c4691db374d4762f15e0  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994917
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994567
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997226
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977549
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998631
#
# tag_id                                    022f8f30c65aaeb13def1fb9d700c1937e30da06  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994885
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994129
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997931
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978645
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998154
#
# tag_id                                    0245aa04713eb538ebcb6d6c5667a55f5920d535  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.995028
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994458
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997286
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977626
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998492
#
# tag_id                                    02a5da421359cb69816444a48f35c0cb01806ca6  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994931
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994583
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997234
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977776
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998635
#
# tag_id                                    ...  \
# user_id                                   ...
# 00000055a78bf6735c4a89358fab1de34104c3cb  ...
# 000014674d2afbd30b4a89e7f917b67ade3c31c4  ...
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9  ...
# 00009c599dca6873a47404fa9b7a9b0a1bd13049  ...
# 0000a8c248465bc8cd907e112b5c2f1e94424f28  ...
#
# tag_id                                    fd9b6d215102521471bdd20b88eef7e471a5f08c  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994890
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994258
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997720
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978102
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998321
#
# tag_id                                    fde652531ae50c7def995f5c5c2b067cd9bdc9de  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994994
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.995042
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.996982
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.976915
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998914
#
# tag_id                                    fe0f9fd1fdfe652523ed4a3a9e57375301bf7144  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994898
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994267
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997490
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977747
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998324
#
# tag_id                                    fe2297da6fbc7992a934f8ce4c848584d73bd1c3  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994923
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994574
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997227
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977656
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998632
#
# tag_id                                    fe5cd317975ca5dada3d9d047133f1925e460053  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994972
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994451
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997423
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978182
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998453
#
# tag_id                                    fe9cd8d22101c48eca5bc3eee51b9dc5e07fe683  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.995018
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994768
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997109
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977269
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998765
#
# tag_id                                    fe9e7151b6ae2070c053a80fa37862cfef449cae  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994903
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994422
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997486
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978092
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998482
#
# tag_id                                    fed8505b88adf6d879b4df147b29a068d98faa72  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994923
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994316
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997602
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.978414
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998285
#
# tag_id                                    ff0257af2bc7c28cd397a820aa33cde0d04b58b8  \
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.994998
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994627
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997319
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977681
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998511
#
# tag_id                                    ff0d3fb21c00bc33f71187a2beec389e9eff5332
# user_id
# 00000055a78bf6735c4a89358fab1de34104c3cb                                  0.995137
# 000014674d2afbd30b4a89e7f917b67ade3c31c4                                  0.994439
# 00001dbe00e56fc4b1c1b65dda63de2a5ece55f9                                  0.997417
# 00009c599dca6873a47404fa9b7a9b0a1bd13049                                  0.977880
# 0000a8c248465bc8cd907e112b5c2f1e94424f28                                  0.998450
#
# [5 rows x 989 columns]

# %%
eval_model(euclidean_predictions_df, test_df)
# Out:
# Recall: 3.0084254870984717
# Precision: 0.5127284511170768

# %% [markdown]
# ### Final comments:
# - Euclidean distance model showed the best performance of all, but close to the cosine.
# - Matrix decomposition is a good approach for high dimentional datasets, but underperforms against simple distance metrics
# - A better evaluation scheme should be used to draw final conclusions, for instance, with fold cross validation
